# %% [markdown]
# The most common example of a system that exhibits chaos is the double pendulum. In the double pendulum setting we know that small perturbations to the initial conditions significantly influence the trajectory. How best can we capture such changes?

# %% [markdown]
# The lagrangian of a system is:

# %% [markdown]
# $$ L = T(q,\dot{q}) - V(q) $$ and $$ \frac{d}{dt}\frac{\partial L}{\partial \dot{q}} - \frac{\partial L}{\partial q} = \tau$$

# %% [markdown]
# gives us the Euler-Lagrange equation with generalized forces

# %% [markdown]
# If $ T = \dot{q}^T M(q) \dot{q} $ and V is only a function of q, then:
#
# $$ \frac{\partial L}{\partial \dot{q}} = p = M(q)\dot{q}$$
#
# $$ \frac{d}{dt}\frac{\partial L}{\partial \dot{q}} = \frac{dp}{dt} = \dot{M(q)}\dot{q} + M(q)\ddot{q} $$
#
# Then,if we have no generalized forces:
#
# $$\dot{M(q)}\dot{q} + M(q)\ddot{q} - \frac{\partial L}{\partial q} = 0 $$
#
# $$ \ddot{q} = M(q)^{-1} (\frac{\partial L}{\partial q} - \dot{M(q)} \dot{q}) $$

# %% [markdown]
# Deep Lagrangian Nets https://arxiv.org/pdf/1907.04490.pdf - solves the above equation by learning each component and breaking the lagrangian L into a lower triangular times its transpose.

# %% [markdown]
# One unique aspect about VIGN is that we don't need to explicitly model the time derivative of M which is a bottle neck of the approach given above. so:
#
# Given $[q_t,\dot{q_t}]$ $\rightarrow$ L $\rightarrow [p_t,\dot{p_t}] $ so now the state is basically:
#
# given our initial state, we want to be able to update $[q_t,\dot{q_t}]$, the way to do this is:

# %% [markdown]
# $$ dq_t/dt = \dot{q_t}$$
# $$ dp_t/dt = dL/dq $$

# %% [markdown]
# $$[q_{t+1},p_{t+1}] $$, but, if we learn M(q) then $$[q_{t+1},M^{-1}(q_{t+1})p_{t+1})]$$

# %% [markdown]
# ***

# %%
from data_builder import *
from utils import *
from model import *
import numpy as np
import time

# %%
expt_name = 'test'
num_trajectories = 1
n_test_traj = 1
num_nodes = 2
T_max = 10.01
dt = 0.01
srate = 0.01
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)


train_data = doublepend( expt_name, num_trajectories, num_nodes, T_max, dt, srate, 1)
valid_data = doublepend( expt_name, n_test_traj, num_nodes, 2*T_max,dt,srate, 1)
# Out:
# cpu

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1,y1,x2,y2 = theta_to_cart(train_data['x'])
x1_t,y1_t,x2_t,y2_t = theta_to_cart(valid_data['x'])

# %%
import seaborn as sns

# %%
# sns.scatterplot(x=x1,y=y1)
sns.scatterplot(x=x2,y=y2)
# sns.scatterplot(x=x1,y=y1)
sns.scatterplot(x=x2_t,y=y2_t)

# %%
tnow,tnext = nownext(train_data,num_trajectories,num_nodes,T_max,dt,srate,spatial_dim=2)

# %%
traindat = pendpixdata(tnow[0], tnext[0])
train_dataloader = DataLoader(traindat, batch_size=50, num_workers=2, shuffle=True)
# # valdat = pendpixdata(test_xnow, test_xnext)
# val_dataloader = DataLoader(valdat, batch_size=bs_test, num_workers=nw, shuffle=False)
data_dict = {'train': train_dataloader}

running_losses = 0.

def train_model(model, optimizer, num_epochs=1):

    for epoch in range(num_epochs):
        print('epoch:{}'.format(epoch))

        # Each epoch has a training and validation phase
        for phase in ['train']:
            if phase == 'train':
                # scheduler.step()
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            # Iterate over data.
            for batch_i, (q, dq) in enumerate(data_dict[phase]):
                if phase == 'train':
                    optimizer.zero_grad()
                q, next_step_true = q.float(), dq.float()
                q.to(device)
                next_step_true.to(device)
                q.requires_grad = True
                loss = 0
#                 print(q.shape)
                if phase == 'train':
                    t1 =time.time()
                    next_step_pred = model.next_step(q)
                    phat_via_m = ((model.M_matrix(q[:,:2]))@(q[:,2:].reshape(-1,1))).reshape(-1,2)
                    phat_via_l = model.Lpartials(q)[:,2:]
#                     print(f'running time next pred: {time.time()-t1}')
                    loss += ((next_step_pred - next_step_true) ** 2).mean() 
#                     loss += ((phat_via_m-phat_via_l)**2).mean()
                    (loss).backward()
                    optimizer.step()

                if phase == 'valid':
                    # print(q.shape)
                    t1 = time.time()
                    next_step_pred_roll = validator(deriv_fun, bs_test, q[0].reshape(-1, 2),ssr)
#                     print(f'running time validation: {time.time() - t1}')

                    loss += ((next_step_pred_roll - next_step_true) ** 2).mean()

                running_loss += loss.item()
            epoch_loss = running_loss
            print('{} Loss: {:.10f} Acc: {:.4f}'.format(phase, epoch_loss, 1))

    return model


model_ft = MODEL(4, 200, 1)
params = list(model_ft.parameters())
optimizer_ft = torch.optim.Adam(params, 1e-3)
model_ft = train_model(model_ft, optimizer_ft, num_epochs=100)
# Out:
# epoch:0
# train Loss: 0.1638515750 Acc: 1.0000
# epoch:1
# train Loss: 0.1540846303 Acc: 1.0000
# epoch:2
# train Loss: 0.1514024502 Acc: 1.0000
# epoch:3
# train Loss: 0.1494299495 Acc: 1.0000
# epoch:4
# train Loss: 0.1479365174 Acc: 1.0000
# epoch:5
# train Loss: 0.1463473896 Acc: 1.0000
# epoch:6
# train Loss: 0.1442744690 Acc: 1.0000
# epoch:7
# train Loss: 0.1416412978 Acc: 1.0000
# epoch:8
# train Loss: 0.1384372083 Acc: 1.0000
# epoch:9
# train Loss: 0.1339115468 Acc: 1.0000
# epoch:10
# train Loss: 0.1274277996 Acc: 1.0000
# epoch:11
# train Loss: 0.1183121237 Acc: 1.0000
# epoch:12
# train Loss: 0.1064409441 Acc: 1.0000
# epoch:13
# train Loss: 0.0928012608 Acc: 1.0000
# epoch:14
# train Loss: 0.0775874991 Acc: 1.0000
# epoch:15
# train Loss: 0.0606205866 Acc: 1.0000
# epoch:16
# train Loss: 0.0462508672 Acc: 1.0000
# epoch:17
# train Loss: 0.0366478164 Acc: 1.0000
# epoch:18
# train Loss: 0.0311094433 Acc: 1.0000
# epoch:19
# train Loss: 0.0282443031 Acc: 1.0000
# epoch:20
# train Loss: 0.0248138780 Acc: 1.0000
# epoch:21
# train Loss: 0.0223556795 Acc: 1.0000
# epoch:22
# train Loss: 0.0207344466 Acc: 1.0000
# epoch:23
# train Loss: 0.0193124621 Acc: 1.0000
# epoch:24
# train Loss: 0.0186483268 Acc: 1.0000
# epoch:25
# train Loss: 0.0171261311 Acc: 1.0000
# epoch:26
# train Loss: 0.0157857359 Acc: 1.0000
# epoch:27
# train Loss: 0.0148671478 Acc: 1.0000
# epoch:28
# train Loss: 0.0140691636 Acc: 1.0000
# epoch:29
# train Loss: 0.0132840112 Acc: 1.0000
# epoch:30
# train Loss: 0.0127028482 Acc: 1.0000
# epoch:31
# train Loss: 0.0120657844 Acc: 1.0000
# epoch:32
# train Loss: 0.0012558295 Acc: 1.0000
# epoch:86
# train Loss: 0.0011124697 Acc: 1.0000
# epoch:87
# train Loss: 0.0009794554 Acc: 1.0000
# epoch:88
# train Loss: 0.0008918111 Acc: 1.0000
# epoch:89
# train Loss: 0.0008067371 Acc: 1.0000
# epoch:90
# train Loss: 0.0007691539 Acc: 1.0000
# epoch:91
# train Loss: 0.0007693452 Acc: 1.0000
# epoch:92
# train Loss: 0.0006297543 Acc: 1.0000
# epoch:93
# train Loss: 0.0005844759 Acc: 1.0000
# epoch:94
# train Loss: 0.0005511069 Acc: 1.0000
# epoch:95
# train Loss: 0.0005168878 Acc: 1.0000
# epoch:96
# train Loss: 0.0005080264 Acc: 1.0000
# epoch:97
# train Loss: 0.0004735810 Acc: 1.0000
# epoch:98
# train Loss: 0.0004538117 Acc: 1.0000
# epoch:99
# train Loss: 0.0004585072 Acc: 1.0000

# %%
q=torch.tensor(tnow[0][0]).float().reshape(-1,4)
q.to(device)
q.requires_grad = True
loss = 0
coll = []
for _ in range(1000):
    nstep = model_ft.next_step(q)
    coll.append(nstep.detach().numpy()[0])
    q=nstep
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-faf13be74e32> in <module>
#       5 coll = []
#       6 for _ in range(1000):
# ----> 7     nstep = model_ft.next_step(q)
#       8     coll.append(nstep.detach().numpy()[0])
#       9     q=nstep
#
# ~/Desktop/chaos_systems/model.py in next_step(self, x)
#     115         q_init = x[:, :2]
#     116         init_param = torch.cat([q_init, p_init], 1)
# --> 117         next_set = self.rk4(self.time_deriv, init_param,self.dt)
#     118         qdot = (self.Minv @ (next_set[:, 2:].reshape(-1, 1))).reshape(-1, 2)
#     119         return torch.cat([next_set[:,:2],qdot],1)
#
# ~/Desktop/chaos_systems/model.py in rk4(self, dx_dt_fn, x_t, dt)
#      62         k2 = dt * dx_dt_fn(x_t + (1 / 2) * k1)
#      63         k3 = dt * dx_dt_fn(x_t + (1 / 2) * k2)
# ---> 64         k4 = dt * dx_dt_fn(x_t + k3)
#      65         x_tp1 = x_t + (1 / 6) * (k1 + k2 * 2 + k3 * 2 + k4)
#      66         return x_tp1
#
# ~/Desktop/chaos_systems/model.py in time_deriv(self, x, p, separate_fields)
#     131         q = x[:,:2]
#     132         qdot = (self.Minv@(x[:,2:].reshape(-1,1))).reshape(-1,2)
# --> 133         Lpartials = self.Lpartials(torch.cat([q, qdot], 1))
#     134         pdot = Lpartials[:,:2]
#     135
#
# ~/Desktop/chaos_systems/model.py in Lpartials(self, x)
#     121     def Lpartials(self,x):
#     122         F2 = self.forward(x)  # traditional forward pass
# --> 123         dF2 = torch.autograd.grad(F2.sum(), x, create_graph=True)[0]  # gradients for solenoidal field
#     124         return dF2
#     125     def time_deriv(self, x, p=False, separate_fields=False):
#
# ~/anaconda3/envs/main/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     190     return Variable._execution_engine.run_backward(
#     191         outputs, grad_outputs, retain_graph, create_graph,
# --> 192         inputs, allow_unused)
#     193
#     194
#
# KeyboardInterrupt:

# %%
x1_p,y1_p,x2_p,y2_p = theta_to_cart(np.array(coll))

# %%
x1_p.shape
# Out:
# (526,)

# %%
sns.scatterplot(x=x2_p,y=y2_p)
sns.scatterplot(x=x2[:500],y=y2[:500])

# %%
x2.shape
# Out:
# (1001,)
