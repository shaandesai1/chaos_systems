# %% [markdown]
# The most common example of a system that exhibits chaos is the double pendulum. In the double pendulum setting we know that small perturbations to the initial conditions significantly influence the trajectory. How best can we capture such changes?

# %% [markdown]
# The lagrangian of a system is:

# %% [markdown]
# $$ L = T(q,\dot{q}) - V(q) $$ and $$ \frac{d}{dt}\frac{\partial L}{\partial \dot{q}} - \frac{\partial L}{\partial q} = \tau$$

# %% [markdown]
# gives us the Euler-Lagrange equation with generalized forces

# %% [markdown]
# If $ T = \dot{q}^T M(q) \dot{q} $ and V is only a function of q, then:
#
# $$ \frac{\partial L}{\partial \dot{q}} = p = M(q)\dot{q}$$
#
# $$ \frac{d}{dt}\frac{\partial L}{\partial \dot{q}} = \frac{dp}{dt} = \dot{M(q)}\dot{q} + M(q)\ddot{q} $$
#
# Then,if we have no generalized forces:
#
# $$\dot{M(q)}\dot{q} + M(q)\ddot{q} - \frac{\partial L}{\partial q} = 0 $$
#
# $$ \ddot{q} = M(q)^{-1} (\frac{\partial L}{\partial q} - \dot{M(q)} \dot{q}) $$

# %% [markdown]
# Deep Lagrangian Nets https://arxiv.org/pdf/1907.04490.pdf - solves the above equation by learning each component and breaking the lagrangian L into a lower triangular times its transpose.

# %% [markdown]
# One unique aspect about VIGN is that we don't need to explicitly model the time derivative of M which is a bottle neck of the approach given above. so:
#
# Given $[q_t,\dot{q_t}]$ $\rightarrow$ L $\rightarrow [p_t,\dot{p_t}] $ so now the state is basically:
#
# given our initial state, we want to be able to update $[q_t,\dot{q_t}]$, the way to do this is:

# %% [markdown]
# $$ dq_t/dt = \dot{q_t}$$
# $$ dp_t/dt = dL/dq $$

# %% [markdown]
# $$[q_{t+1},p_{t+1}] $$, but, if we learn M(q) then $$[q_{t+1},M^{-1}(q_{t+1})p_{t+1})]$$

# %% [markdown]
# ***

# %%
from data_builder import *
from utils import *
from model import *
import numpy as np
import time
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
expt_name = 'test'
num_trajectories = 1
n_test_traj = 1
num_nodes = 2
T_max = 10.01
dt = 0.01
srate = 0.01
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)


train_data = doublepend( expt_name, num_trajectories, num_nodes, T_max, dt, srate, 0,yflag=False)
valid_data = doublepend( expt_name, n_test_traj, num_nodes, 2*T_max,dt,srate, 0,yflag=False)
# Out:
# cpu

# %%
x1,y1,x2,y2 = theta_to_cart(train_data['x'])
x1_t,y1_t,x2_t,y2_t = theta_to_cart(valid_data['x'])

# %%
sns.scatterplot(x=x1,y=y1)
sns.scatterplot(x=x2,y=y2)
# Out:
# <AxesSubplot:>

# %%
train_data['dx']
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00, -6.40780970e-01,
#         -9.25487895e+00],
#        [-6.38710267e-03, -9.25552170e-02, -6.34568963e-01,
#         -9.25680756e+00],
#        [-1.26499755e-02, -1.85149041e-01, -6.15936049e-01,
#         -9.26260395e+00],
#        ...,
#        [ 2.09842092e+00,  1.01524235e+00,  8.72698749e+00,
#         -9.84172111e+00],
#        [ 2.18482274e+00,  9.16396601e-01,  8.55064090e+00,
#         -9.92181193e+00],
#        [ 2.26937324e+00,  8.16930763e-01,  8.35612057e+00,
#         -9.96447702e+00]])

# %%
def omega(state):
    pt1 = state[:,2] + state[:,3]*np.cos(state[:,0]-state[:,1])
    pt2 = state[:,3] + state[:,2]*np.cos(state[:,0]-state[:,1])
    return np.concatenate([state[:,:2],pt1.reshape(-1,1),pt2.reshape(-1,1)],1)

# %%
tnow,tnext = nownext(train_data,num_trajectories,num_nodes,T_max,dt,srate,spatial_dim=2)
tnow = omega(tnow[0])
tnext = omega(tnext[0])

# %%
traindat = pendpixdata(train_data['x'], train_data['dx'])
train_dataloader = DataLoader(traindat, batch_size=200, num_workers=2, shuffle=True)
# # valdat = pendpixdata(test_xnow, test_xnext)
# val_dataloader = DataLoader(valdat, batch_size=bs_test, num_workers=nw, shuffle=False)
data_dict = {'train': train_dataloader}
running_losses = 0.
loss_collater = []
torch.pi = torch.tensor(np.pi)
def rebase(q):
#     return q
    qs= torch.fmod((q[:,:2] + torch.pi) , (2 * torch.pi)) - torch.pi
    qdots = q[:,2:]
    return torch.cat([qs,qdots],1)
def train_model(model, optimizer, num_epochs=1):

    for epoch in range(num_epochs):
        print('epoch:{}'.format(epoch))

        # Each epoch has a training and validation phase
        for phase in ['train']:
            if phase == 'train':
                # scheduler.step()
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            # Iterate over data.
            for batch_i, (q, q_next) in enumerate(data_dict[phase]):
                if phase == 'train':
                    optimizer.zero_grad()
                q, q_next = q.float(), q_next.float()
                q.to(device)
                q_next.to(device)
                q.requires_grad = True
                loss = 0
                energy_ = torch.ones(size=q.shape)*train_data['energy'][0]
                if phase == 'train':
                    t1 =time.time()
                    next_step_pred = model.next_step(q)
                    state_loss = ((next_step_pred - q_next) ** 2).mean()
                    energy_loss = 0#((model.forward(rebase(q))-energy_)**2).mean()
                    loss +=  state_loss + energy_loss
                    (loss).backward()
                    print(f'energy:{energy_loss},state:{state_loss}')
                    optimizer.step()
                    loss_collater.append((state_loss,energy_loss))
                running_loss += loss.item()
                    
            epoch_loss = running_loss
            print('{} Loss: {:.10f}'.format(phase, epoch_loss))

            
    return model


model_ft = MODEL(4, 200, 1)
params = list(model_ft.parameters())
optimizer_ft = torch.optim.Adam(params, 1e-2)
model_ft = train_model(model_ft, optimizer_ft, num_epochs=1000)
# Out:
# epoch:0
# energy:0,state:0.0019948745612055063
# energy:0,state:0.001985999522730708
# energy:0,state:0.0022548320703208447
# energy:0,state:0.002045791130512953
# energy:0,state:0.002304613357409835
# train Loss: 0.0105861106
# epoch:1
# energy:0,state:0.0019436216680333018
# energy:0,state:0.0019292798824608326
# energy:0,state:0.002235172549262643
# energy:0,state:0.002041225554421544
# energy:0,state:0.002297441242262721
# train Loss: 0.0104467409
# epoch:2
# energy:0,state:0.001940307323820889
# energy:0,state:0.0019333437085151672
# energy:0,state:0.0022338286507874727
# energy:0,state:0.0020329896360635757
# energy:0,state:0.002295305486768484
# train Loss: 0.0104357748
# epoch:3
# energy:0,state:0.0019353167153894901
# energy:0,state:0.001940102782100439
# energy:0,state:0.002234379295259714
# energy:0,state:0.0020244447514414787
# energy:0,state:0.002295508049428463
# train Loss: 0.0104297516
# epoch:4
# energy:0,state:0.001929208287037909
# energy:0,state:0.0019475518492981791
# energy:0,state:0.0022358177229762077
# energy:0,state:0.00201583094894886
# energy:0,state:0.002295955317094922
# train Loss: 0.0104243641
# epoch:5
# energy:0,state:0.0019235971849411726
# energy:0,state:0.001955397194251418
# energy:0,state:0.0022373057436197996
# energy:0,state:0.002007781993597746
# energy:0,state:0.0022953979205340147
# train Loss: 0.0104194800
# epoch:6
# energy:0,state:0.0019196337088942528
# energy:0,state:0.00196271575987339
# energy:0,state:0.002237950684502721
# energy:0,state:0.002000704174861312
# energy:0,state:0.0022938509937375784
# train Loss: 0.0104148553
# epoch:7
# energy:0,state:0.001917312853038311
# energy:0,state:0.0019687495660036802
# energy:0,state:0.002237744862213731
# energy:0,state:0.0019944608211517334
# energy:0,state:0.0022923098877072334
# train Loss: 0.0104105780
# epoch:8
# energy:0,state:0.00191610271576792
# energy:0,state:0.001973300939425826
# energy:0,state:0.0022372098173946142
# energy:0,state:0.0019883897621184587
# energy:0,state:0.002290932461619377
# train Loss: 0.0104059357
# epoch:9
# energy:0,state:0.0019157923525199294
# energy:0,state:0.001976621337234974
# energy:0,state:0.0022365618497133255
# energy:0,state:0.001982430461794138
# energy:0,state:0.002288960153236985
# train Loss: 0.0104003662
# epoch:10
# energy:0,state:0.0019166483543813229
# energy:0,state:0.001978805288672447
# energy:0,state:0.0022353208623826504
# energy:0,state:0.0019772001542150974
# energy:0,state:0.0022859242744743824
# train Loss: 0.0103938989
# epoch:11
# energy:0,state:0.0019187047146260738
# energy:0,state:0.0019799675792455673
# energy:0,state:0.0022331103682518005
# energy:0,state:0.001972380094230175
# energy:0,state:0.002282000845298171
# train Loss: 0.0103861636
# epoch:12
# energy:0,state:0.0019216143991798162
# energy:0,state:0.001981141045689583
# energy:0,state:0.002230304293334484
# energy:0,state:0.001966714160516858
# energy:0,state:0.002277276013046503
# train Loss: 0.0103770499
# epoch:13
# energy:0,state:0.0019256370142102242
# energy:0,state:0.00198287982493639
# energy:0,state:0.0022266078740358353
# energy:0,state:0.0019602756947278976
# energy:0,state:0.002271892037242651
# train Loss: 0.0103672924
# epoch:14
# energy:0,state:0.0019320191349834204
# energy:0,state:0.0019831466488540173
# energy:0,state:0.002220685128122568
# energy:0,state:0.001954483799636364
# energy:0,state:0.0022666410077363253
# train Loss: 0.0103569757
# epoch:15
# energy:0,state:0.0019415394635871053
# energy:0,state:0.0019802977330982685
# energy:0,state:0.002212286228314042
# energy:0,state:0.0019490531412884593
# energy:0,state:0.00226224516518414
# train Loss: 0.0103454217
# epoch:16
# energy:0,state:0.0019536172039806843
# energy:0,state:0.001976389903575182
# energy:0,state:0.0022019369062036276
# energy:0,state:0.0019430624088272452
# energy:0,state:0.0022594307083636522
# train Loss: 0.0103344371
# epoch:17
# energy:0,state:0.001967170275747776
# energy:0,state:0.0019711125642061234
# energy:0,state:0.002189554972574115
# energy:0,state:0.0019371616654098034
# energy:0,state:0.0022586574777960777
# train Loss: 0.0103236570
# epoch:18
# energy:0,state:0.0019809126388281584
# energy:0,state:0.0019650652538985014
# energy:0,state:0.0021760216914117336
# energy:0,state:0.0019309152849018574
# energy:0,state:0.002259357599541545
# train Loss: 0.0103122725
# epoch:19
# energy:0,state:0.0019936750177294016
# energy:0,state:0.0019600773230195045
# energy:0,state:0.002162730321288109
# energy:0,state:0.0019241741392761469
# energy:0,state:0.0022605718113482
# train Loss: 0.0103012286
# epoch:20
# energy:0,state:0.0020049838349223137
# energy:0,state:0.0019552765879780054
# energy:0,state:0.0021506890188902617
# energy:0,state:0.0019173368345946074
# energy:0,state:0.0022609131410717964
# train Loss: 0.0102891994
# epoch:21
# energy:0,state:0.0020146670285612345
# energy:0,state:0.0019524114904925227
# energy:0,state:0.0021403913851827383
# energy:0,state:0.0019101485377177596
# energy:0,state:0.0022593019530177116
# train Loss: 0.0102769204
# epoch:22
# energy:0,state:0.0020226966589689255
# energy:0,state:0.001951593323610723
# energy:0,state:0.0021314143668860197
# energy:0,state:0.0019034543074667454
# energy:0,state:0.0022553387098014355
# train Loss: 0.0102644974
# epoch:23
# energy:0,state:0.0020287029910832644
# energy:0,state:0.0019520801724866033
# energy:0,state:0.0021230708807706833
# energy:0,state:0.0018980918684974313
# energy:0,state:0.0022492033895105124
# train Loss: 0.0102511493
# epoch:24
# energy:0,state:0.0020328161772340536
# energy:0,state:0.0019527280237525702
# energy:0,state:0.0021146961953490973
# energy:0,state:0.0018933187238872051
# energy:0,state:0.0022439805325120687
# train Loss: 0.0102375397
# epoch:25
# energy:0,state:0.002037799684330821
# energy:0,state:0.001952625229023397
# energy:0,state:0.0021052523516118526
# energy:0,state:0.0018874118104577065
# energy:0,state:0.0022419688757508993
# train Loss: 0.0102250580
# epoch:26
# energy:0,state:0.002044183202087879
# energy:0,state:0.0019524118397384882
# energy:0,state:0.0020937565714120865
# energy:0,state:0.0018800839316099882
# energy:0,state:0.002242283197119832
# train Loss: 0.0102127187
# epoch:27
# energy:0,state:0.0020515229552984238
# energy:0,state:0.001951869111508131
# energy:0,state:0.0020822552032768726
# energy:0,state:0.001873314380645752
# energy:0,state:0.0022418100852519274
# train Loss: 0.0102007717
# epoch:28
# energy:0,state:0.0020586124155670404
# energy:0,state:0.001951308804564178
# energy:0,state:0.0020720860920846462
# energy:0,state:0.001868356135673821
# energy:0,state:0.002240285277366638
# train Loss: 0.0101906487
# epoch:29
# energy:0,state:0.0020642320159822702
# energy:0,state:0.0019509431440383196
# energy:0,state:0.0020623737946152687
# energy:0,state:0.001864299876615405
# energy:0,state:0.0022399434819817543
# train Loss: 0.0101817923
# epoch:30
# energy:0,state:0.002068743808194995
# energy:0,state:0.0019502752693369985
# energy:0,state:0.0020526545122265816
# energy:0,state:0.0018597316229715943
# energy:0,state:0.002240181900560856
# train Loss: 0.0101715871
# epoch:31
# energy:0,state:0.0020727834198623896
# energy:0,state:0.001950618578121066
# energy:0,state:0.0020438190549612045
# energy:0,state:0.0018543399637565017
# energy:0,state:0.002239388879388571
# train Loss: 0.0101609499
# epoch:32
# energy:0,state:0.0020761501509696245
# energy:0,state:0.001952907769009471
# energy:0,state:0.002035822719335556
# energy:0,state:0.0018482283921912313
# energy:0,state:0.0022377625573426485
# train Loss: 0.0101508716
# epoch:33
# energy:0,state:0.002078707329928875
# energy:0,state:0.001956374617293477
# energy:0,state:0.0020279258023947477
# energy:0,state:0.0018413984216749668
# energy:0,state:0.0022359369322657585
# train Loss: 0.0101403431
# epoch:34
# energy:0,state:0.0020812645088881254
# energy:0,state:0.0019602258689701557
# energy:0,state:0.0020199143327772617
# energy:0,state:0.0018340754322707653
# energy:0,state:0.002233808394521475
# train Loss: 0.0101292885
# epoch:35
# energy:0,state:0.002084416802972555
# energy:0,state:0.0019643327686935663
# energy:0,state:0.002011306583881378
# energy:0,state:0.00182623032014817
# energy:0,state:0.0022320151329040527
# train Loss: 0.0101183016
# epoch:36
# energy:0,state:0.0020877935457974672
# energy:0,state:0.0019688578322529793
# energy:0,state:0.0020017819479107857
# energy:0,state:0.0018178720492869616
# energy:0,state:0.0022306323517113924
# train Loss: 0.0101069377
# epoch:37
# energy:0,state:0.002091706730425358
# energy:0,state:0.001973214792087674
# energy:0,state:0.0019917043391615152
# energy:0,state:0.0018094185506924987
# energy:0,state:0.0022290037013590336
# train Loss: 0.0100950481
# epoch:38
# energy:0,state:0.0020963321439921856
# energy:0,state:0.001977497013285756
# energy:0,state:0.001981097972020507
# energy:0,state:0.0018005226738750935
# energy:0,state:0.002227166900411248
# train Loss: 0.0100826167
# epoch:39
# energy:0,state:0.0021015936508774757
# energy:0,state:0.0019819072913378477
# energy:0,state:0.0019697726238518953
# energy:0,state:0.0017911085160449147
# energy:0,state:0.0022252481430768967
# train Loss: 0.0100696302
# epoch:40
# energy:0,state:0.0021075934637337923
# energy:0,state:0.0019862966146320105
# energy:0,state:0.0019575348123908043
# energy:0,state:0.0017813293961808085
# energy:0,state:0.002223375951871276
# train Loss: 0.0100561302
# epoch:41
# energy:0,state:0.002114313654601574
# energy:0,state:0.001990080112591386
# energy:0,state:0.0019440349424257874
# energy:0,state:0.0017710508545860648
# energy:0,state:0.002221558475866914
# train Loss: 0.0100410380
# epoch:42
# energy:0,state:0.0021213837899267673
# energy:0,state:0.001994368387386203
# energy:0,state:0.0019297824474051595
# energy:0,state:0.001760860555805266
# energy:0,state:0.002220343565568328
# train Loss: 0.0100267387
# epoch:43
# energy:0,state:0.0021288208663463593
# energy:0,state:0.001997516257688403
# energy:0,state:0.001914503751322627
# energy:0,state:0.0017511210171505809
# energy:0,state:0.0022203095722943544
# train Loss: 0.0100122715
# epoch:44
# energy:0,state:0.0021363012492656708
# energy:0,state:0.001998805906623602
# energy:0,state:0.0018978695152327418
# energy:0,state:0.0017423279350623488
# energy:0,state:0.0022214329801499844
# train Loss: 0.0099967376
# epoch:45
# energy:0,state:0.0021433590445667505
# energy:0,state:0.0019994929898530245
# energy:0,state:0.0018806905718520284
# energy:0,state:0.0017348676919937134
# energy:0,state:0.0022237517405301332
# train Loss: 0.0099821620
# epoch:46
# energy:0,state:0.002149504143744707
# energy:0,state:0.0019993300084024668
# energy:0,state:0.0018631011480465531
# energy:0,state:0.0017283833585679531
# energy:0,state:0.0022266963496804237
# train Loss: 0.0099670150
# epoch:47
# energy:0,state:0.002155484165996313
# energy:0,state:0.0019984364043921232
# energy:0,state:0.0018454082310199738
# energy:0,state:0.0017222909955307841
# energy:0,state:0.002229488454759121
# train Loss: 0.0099511083
# epoch:48
# energy:0,state:0.0021604972425848246
# energy:0,state:0.0020000101067125797
# energy:0,state:0.0018290154403075576
# energy:0,state:0.0017160945571959019
# energy:0,state:0.0022320719435811043
# train Loss: 0.0099376893
# epoch:49
# energy:0,state:0.0021658586338162422
# energy:0,state:0.0019990711007267237
# energy:0,state:0.0018125191563740373
# energy:0,state:0.0017098530661314726
# energy:0,state:0.0022343099117279053
# train Loss: 0.0099216119
# epoch:50
# energy:0,state:0.002170207444578409
# energy:0,state:0.001999789383262396
# energy:0,state:0.0017959895776584744
# energy:0,state:0.0017030313611030579
# energy:0,state:0.0022356705740094185
# train Loss: 0.0099046883
# epoch:51
# energy:0,state:0.002175290836021304
# energy:0,state:0.00200124504044652
# energy:0,state:0.0017803939990699291
# energy:0,state:0.0016961055807769299
# energy:0,state:0.0022367157507687807
# train Loss: 0.0098897512
# epoch:52
# energy:0,state:0.0021799730602651834
# energy:0,state:0.0020030352752655745
# energy:0,state:0.0017644426552578807
# energy:0,state:0.0016884938813745975
# energy:0,state:0.0022369064390659332
# train Loss: 0.0098728513
# epoch:53
# energy:0,state:0.0021857572719454765
# energy:0,state:0.0020054439082741737
# energy:0,state:0.0017496836371719837
# energy:0,state:0.00168029370252043
# energy:0,state:0.0022365767508745193
# train Loss: 0.0098577553
# epoch:54
# energy:0,state:0.0021911393851041794
# energy:0,state:0.002008209004998207
# energy:0,state:0.0017341140192002058
# energy:0,state:0.0016714681405574083
# energy:0,state:0.0022357183042913675
# train Loss: 0.0098406489
# epoch:55
# energy:0,state:0.0021976190619170666
# energy:0,state:0.002011488424614072
# energy:0,state:0.0017199749127030373
# energy:0,state:0.001661980408243835
# energy:0,state:0.002235027030110359
# train Loss: 0.0098260898
# epoch:56
# energy:0,state:0.002203945303335786
# energy:0,state:0.0020144234877079725
# energy:0,state:0.0017042688559740782
# energy:0,state:0.0016517023323103786
# energy:0,state:0.002233608392998576
# train Loss: 0.0098079484
# epoch:57
# energy:0,state:0.002211409853771329
# energy:0,state:0.0020190009381622076
# energy:0,state:0.0016909129917621613
# energy:0,state:0.0016402075998485088
# energy:0,state:0.002232443308457732
# train Loss: 0.0097939747
# epoch:58
# energy:0,state:0.0022188955917954445
# energy:0,state:0.0020215001422911882
# energy:0,state:0.0016749792266637087
# energy:0,state:0.0016287463949993253
# energy:0,state:0.0022304230369627476
# train Loss: 0.0097745444
# epoch:59
# energy:0,state:0.0022272393107414246
# energy:0,state:0.002027680166065693
# energy:0,state:0.0016630471218377352
# energy:0,state:0.0016153976321220398
# energy:0,state:0.0022289759945124388
# train Loss: 0.0097623402
# epoch:60
# energy:0,state:0.0022357364650815725
# energy:0,state:0.00202876515686512
# energy:0,state:0.0016464319778606296
# energy:0,state:0.0016031940467655659
# energy:0,state:0.0022261179983615875
# train Loss: 0.0097402456
# epoch:61
# energy:0,state:0.0022444655187427998
# energy:0,state:0.002037688158452511
# energy:0,state:0.0016370135126635432
# energy:0,state:0.0015882888110354543
# energy:0,state:0.0022244069259613752
# train Loss: 0.0097318629
# epoch:62
# energy:0,state:0.0022540888749063015
# energy:0,state:0.002034285571426153
# energy:0,state:0.001618394278921187
# energy:0,state:0.001576961250975728
# energy:0,state:0.0022202152758836746
# train Loss: 0.0097039453
# epoch:63
# energy:0,state:0.002262523863464594
# energy:0,state:0.0020482197869569063
# energy:0,state:0.0016138821374624968
# energy:0,state:0.0015601798659190536
# energy:0,state:0.0022184234112501144
# train Loss: 0.0097032291
# epoch:64
# energy:0,state:0.00227465876378119
# energy:0,state:0.0020345919765532017
# energy:0,state:0.001589332241564989
# energy:0,state:0.001553066773340106
# energy:0,state:0.002212350722402334
# train Loss: 0.0096640005
# epoch:65
# energy:0,state:0.002281034365296364
# energy:0,state:0.0020625563338398933
# energy:0,state:0.0015969923697412014
# energy:0,state:0.0015329491579905152
# energy:0,state:0.0022109504789114
# train Loss: 0.0096844827
# epoch:66
# energy:0,state:0.0022973872255533934
# energy:0,state:0.002028306946158409
# energy:0,state:0.0015605844091624022
# energy:0,state:0.001539172139018774
# energy:0,state:0.0022022738121449947
# train Loss: 0.0096277245
# epoch:67
# energy:0,state:0.0022994212340563536
# energy:0,state:0.002078379737213254
# energy:0,state:0.0015826548915356398
# energy:0,state:0.0015140934847295284
# energy:0,state:0.002205842873081565
# train Loss: 0.0096803922
# epoch:68
# energy:0,state:0.0023166558239609003
# energy:0,state:0.0020148304756730795
# energy:0,state:0.001523893792182207
# energy:0,state:0.0015357926022261381
# energy:0,state:0.0021931766532361507
# train Loss: 0.0095843493
# epoch:69
# energy:0,state:0.002316116588190198
# energy:0,state:0.0020701249595731497
# energy:0,state:0.001537941861897707
# energy:0,state:0.0015038439305499196
# energy:0,state:0.0022127069532871246
# train Loss: 0.0096407343
# epoch:70
# energy:0,state:0.0023171270731836557
# energy:0,state:0.0020065188873559237
# energy:0,state:0.0014651751844212413
# energy:0,state:0.001506398431956768
# energy:0,state:0.002171918284147978
# train Loss: 0.0094671379
# epoch:71
# energy:0,state:0.0023478337097913027
# energy:0,state:0.00207411777228117
# energy:0,state:0.0014697231817990541
# energy:0,state:0.0014700244646519423
# energy:0,state:0.0022017271257936954
# train Loss: 0.0095634263
# epoch:72
# energy:0,state:0.0023411442525684834
# energy:0,state:0.0019907522946596146
# energy:0,state:0.0014275175053626299
# energy:0,state:0.0014717238955199718
# energy:0,state:0.002171145984902978
# train Loss: 0.0094022839
# epoch:73
# energy:0,state:0.0023539147805422544
# energy:0,state:0.0020498111844062805
# energy:0,state:0.001409791293554008
# energy:0,state:0.001446984359063208
# energy:0,state:0.0021941547747701406
# train Loss: 0.0094546564
# epoch:74
# energy:0,state:0.0023531680926680565
# energy:0,state:0.0019865608774125576
# energy:0,state:0.001387851545587182
# energy:0,state:0.0014421406667679548
# energy:0,state:0.0021662102080881596
# train Loss: 0.0093359314
# epoch:75
# energy:0,state:0.0023662690073251724
# energy:0,state:0.002026145812124014
# energy:0,state:0.0013504012022167444
# energy:0,state:0.0014106127200648189
# energy:0,state:0.002168108243495226
# train Loss: 0.0093215370
# epoch:76
# energy:0,state:0.0023725018836557865
# energy:0,state:0.001995863625779748
# energy:0,state:0.0013268199982121587
# energy:0,state:0.0014138725819066167
# energy:0,state:0.002176029374822974
# train Loss: 0.0092850875
# epoch:77
# energy:0,state:0.0023755361326038837
# energy:0,state:0.002004549140110612
# energy:0,state:0.0013037830358371139
# energy:0,state:0.0013859410537406802
# energy:0,state:0.0021687629632651806
# train Loss: 0.0092385723
# epoch:78
# energy:0,state:0.0023967078886926174
# energy:0,state:0.0019875369034707546
# energy:0,state:0.001265184604562819
# energy:0,state:0.0013834561686962843
# energy:0,state:0.002173294546082616
# train Loss: 0.0092061801
# epoch:79
# energy:0,state:0.0023847180418670177
# energy:0,state:0.0020019328221678734
# energy:0,state:0.0012592875864356756
# energy:0,state:0.0013814199483022094
# energy:0,state:0.002179049653932452
# train Loss: 0.0092064081
# epoch:80
# energy:0,state:0.0024102863389998674
# energy:0,state:0.001964139984920621
# energy:0,state:0.0012272398453205824
# energy:0,state:0.0013684607110917568
# energy:0,state:0.002171203726902604
# train Loss: 0.0091413306
# epoch:81
# energy:0,state:0.0023884272668510675
# energy:0,state:0.0019964061211794615
# energy:0,state:0.0012195217423141003
# energy:0,state:0.0013685651356354356
# energy:0,state:0.0021816270891577005
# train Loss: 0.0091545474
# epoch:82
# energy:0,state:0.002409535925835371
# energy:0,state:0.0019367783097550273
# energy:0,state:0.001191396964713931
# energy:0,state:0.0013707773759961128
# energy:0,state:0.002170777413994074
# train Loss: 0.0090792660
# epoch:83
# energy:0,state:0.0023885362315922976
# energy:0,state:0.002028181217610836
# energy:0,state:0.0012051775120198727
# energy:0,state:0.001378238550387323
# energy:0,state:0.0022007531952112913
# train Loss: 0.0092008867
# epoch:84
# energy:0,state:0.0024394160136580467
# energy:0,state:0.0019168731523677707
# energy:0,state:0.00118977518286556
# energy:0,state:0.001377549720928073
# energy:0,state:0.0021737152710556984
# train Loss: 0.0090973293
# epoch:85
# energy:0,state:0.002390750916674733
# energy:0,state:0.0019982897210866213
# energy:0,state:0.001190550741739571
# energy:0,state:0.0013915497111156583
# energy:0,state:0.0022212958429008722
# train Loss: 0.0091924369
# epoch:86
# energy:0,state:0.002410762943327427
# energy:0,state:0.0019456112058833241
# energy:0,state:0.0011899004457518458
# energy:0,state:0.0013977008638903499
# energy:0,state:0.002149481326341629
# train Loss: 0.0090934568
# epoch:87
# energy:0,state:0.0024700891226530075
# energy:0,state:0.0019511376740410924
# energy:0,state:0.001180051825940609
# energy:0,state:0.0014437382342293859
# energy:0,state:0.0022341685835272074
# train Loss: 0.0092791854
# epoch:88
# energy:0,state:0.00237902975641191
# energy:0,state:0.0020019887015223503
# energy:0,state:0.001223928527906537
# energy:0,state:0.0013754182728007436
# energy:0,state:0.002159662311896682
# train Loss: 0.0091400276
# epoch:89
# energy:0,state:0.002495758468285203
# energy:0,state:0.0019175740890204906
# energy:0,state:0.001132128294557333
# energy:0,state:0.001386724878102541
# energy:0,state:0.0021636448800563812
# train Loss: 0.0090958306
# epoch:90
# energy:0,state:0.002338794292882085
# energy:0,state:0.0021157071460038424
# energy:0,state:0.001181453582830727
# energy:0,state:0.0013567551504820585
# energy:0,state:0.002159029943868518
# train Loss: 0.0091517401
# epoch:91
# energy:0,state:0.0024710362777113914
# energy:0,state:0.001876823022030294
# energy:0,state:0.0011236045975238085
# energy:0,state:0.0013475923333317041
# energy:0,state:0.002128881635144353
# train Loss: 0.0089479379
# epoch:92
# energy:0,state:0.0024378958623856306
# energy:0,state:0.0020437396597117186
# energy:0,state:0.0011337638134136796
# energy:0,state:0.0013535398757085204
# energy:0,state:0.002230078913271427
# train Loss: 0.0091990181
# epoch:93
# energy:0,state:0.0023654422257095575
# energy:0,state:0.0018668590346351266
# energy:0,state:0.0011730286059901118
# energy:0,state:0.001422862522304058
# energy:0,state:0.0022074487060308456
# train Loss: 0.0090356411
# epoch:94
# energy:0,state:0.0023933262564241886
# energy:0,state:0.0019148054998368025
# energy:0,state:0.00106075091753155
# energy:0,state:0.0013359403237700462
# energy:0,state:0.002152754459530115
# train Loss: 0.0088575775
# epoch:95
# energy:0,state:0.002425152575597167
# energy:0,state:0.0019513104343786836
# energy:0,state:0.0010411357507109642
# energy:0,state:0.0013896047603338957
# energy:0,state:0.0021789241582155228
# train Loss: 0.0089861277
# epoch:96
# energy:0,state:0.0023325232323259115
# energy:0,state:0.001959028886631131
# energy:0,state:0.0011138601694256067
# energy:0,state:0.001348528079688549
# energy:0,state:0.0021994737908244133
# train Loss: 0.0089534142
# epoch:97
# energy:0,state:0.002447916893288493
# energy:0,state:0.0019034466240555048
# energy:0,state:0.001033813925459981
# energy:0,state:0.0013029013061895967
# energy:0,state:0.002152180764824152
# train Loss: 0.0088402595
# epoch:98
# energy:0,state:0.0024159764871001244
# energy:0,state:0.0019870332907885313
# energy:0,state:0.0010723222512751818
# energy:0,state:0.0013417862355709076
# energy:0,state:0.002208716468885541
# train Loss: 0.0090258347
# epoch:99
# energy:0,state:0.002375273033976555
# energy:0,state:0.0018467966001480818
# energy:0,state:0.001046172110363841
# energy:0,state:0.0013242450077086687
# energy:0,state:0.0021670374553650618
# train Loss: 0.0087595242
# epoch:100
# energy:0,state:0.0023976529482752085
# energy:0,state:0.0019222372211515903
# energy:0,state:0.0009870167123153806
# energy:0,state:0.0013281959109008312
# energy:0,state:0.002161207143217325
# train Loss: 0.0087963099
# epoch:101
# energy:0,state:0.002355109201744199
# energy:0,state:0.0018939217552542686
# energy:0,state:0.0010290113277733326
# energy:0,state:0.00133217079564929
# energy:0,state:0.002182166324928403
# train Loss: 0.0087923794
# epoch:102
# energy:0,state:0.0023631530348211527
# energy:0,state:0.0018886188045144081
# energy:0,state:0.0009803530992940068
# energy:0,state:0.00131479580886662
# energy:0,state:0.002164093777537346
# train Loss: 0.0087110145
# epoch:103
# energy:0,state:0.002378756646066904
# energy:0,state:0.0018526556668803096
# energy:0,state:0.0009633664740249515
# energy:0,state:0.0013139535440132022
# energy:0,state:0.002164676785469055
# train Loss: 0.0086734091
# epoch:104
# energy:0,state:0.0023529171012341976
# energy:0,state:0.0019430519314482808
# energy:0,state:0.0009576207376085222
# energy:0,state:0.0013016721932217479
# energy:0,state:0.0021851074416190386
# train Loss: 0.0087403694
# epoch:105
# energy:0,state:0.0024184442590922117
# energy:0,state:0.001854895381256938
# energy:0,state:0.0009419137495569885
# energy:0,state:0.0012885656906291842
# energy:0,state:0.002158300718292594
# train Loss: 0.0086621198
# epoch:106
# energy:0,state:0.0023820262867957354
# energy:0,state:0.0019063258077949286
# energy:0,state:0.0009550588438287377
# energy:0,state:0.0012933097314089537
# energy:0,state:0.0021683541126549244
# train Loss: 0.0087050748
# epoch:107
# energy:0,state:0.0023988911416381598
# energy:0,state:0.001861213706433773
# energy:0,state:0.0009264673572033644
# energy:0,state:0.0012995543656870723
# energy:0,state:0.0021461290307343006
# train Loss: 0.0086322556
# epoch:108
# energy:0,state:0.0023899078369140625
# energy:0,state:0.0018919841386377811
# energy:0,state:0.000918073405046016
# energy:0,state:0.00129298260435462
# energy:0,state:0.002162942197173834
# train Loss: 0.0086558902
# epoch:109
# energy:0,state:0.0023902764078229666
# energy:0,state:0.001836783834733069
# energy:0,state:0.0008978685946203768
# energy:0,state:0.0012931005330756307
# energy:0,state:0.0021617067977786064
# train Loss: 0.0085797362
# epoch:110
# energy:0,state:0.0023710783571004868
# energy:0,state:0.001901381416246295
# energy:0,state:0.0008914621430449188
# energy:0,state:0.0012891303049400449
# energy:0,state:0.0021668802946805954
# train Loss: 0.0086199325
# epoch:111
# energy:0,state:0.0023935469798743725
# energy:0,state:0.001850945525802672
# energy:0,state:0.0008839380461722612
# energy:0,state:0.001279842690564692
# energy:0,state:0.0021518701687455177
# train Loss: 0.0085601434
# epoch:112
# energy:0,state:0.0023890435695648193
# energy:0,state:0.001862908247858286
# energy:0,state:0.0008799196803011
# energy:0,state:0.0012734334450215101
# energy:0,state:0.0021602765191346407
# train Loss: 0.0085655815
# epoch:113
# energy:0,state:0.0023796604946255684
# energy:0,state:0.001843959209509194
# energy:0,state:0.0008647331851534545
# energy:0,state:0.0012976613361388445
# energy:0,state:0.0021561908069998026
# train Loss: 0.0085422050
# epoch:114
# energy:0,state:0.0023745358921587467
# energy:0,state:0.0018912347732111812
# energy:0,state:0.0008575179381296039
# energy:0,state:0.0012706288835033774
# energy:0,state:0.002161156153306365
# train Loss: 0.0085550736
# epoch:115
# energy:0,state:0.002389553701505065
# energy:0,state:0.0018350646132603288
# energy:0,state:0.0008487857994623482
# energy:0,state:0.001278707874007523
# energy:0,state:0.002153184497728944
# train Loss: 0.0085052965
# epoch:116
# energy:0,state:0.002388100605458021
# energy:0,state:0.0018467494519427419
# energy:0,state:0.0008442869875580072
# energy:0,state:0.0012794886715710163
# energy:0,state:0.0021444314625114202
# train Loss: 0.0085030572
# epoch:117
# energy:0,state:0.002368892077356577
# energy:0,state:0.001879264716990292
# energy:0,state:0.0008429239969700575
# energy:0,state:0.0013095062458887696
# energy:0,state:0.0021775499917566776
# train Loss: 0.0085781370
# epoch:118
# energy:0,state:0.0023830891586840153
# energy:0,state:0.0018543436890468001
# energy:0,state:0.0008592441445216537
# energy:0,state:0.0012702986132353544
# energy:0,state:0.00214834394864738
# train Loss: 0.0085153196
# epoch:119
# energy:0,state:0.0024011051282286644
# energy:0,state:0.0018166456138715148
# energy:0,state:0.0008363467641174793
# energy:0,state:0.0012903877068310976
# energy:0,state:0.002156619681045413
# train Loss: 0.0085011049
# epoch:120
# energy:0,state:0.0023796409368515015
# energy:0,state:0.0018494484247639775
# energy:0,state:0.0008218142320401967
# energy:0,state:0.0013049861881881952
# energy:0,state:0.0021413417998701334
# train Loss: 0.0084972316
# epoch:121
# energy:0,state:0.002360623562708497
# energy:0,state:0.001895515015348792
# energy:0,state:0.0008378252387046814
# energy:0,state:0.0013222642010077834
# energy:0,state:0.002186426892876625
# train Loss: 0.0086026549
# epoch:122
# energy:0,state:0.002408222993835807
# energy:0,state:0.0018372536869719625
# energy:0,state:0.0008619506843388081
# energy:0,state:0.001288777682930231
# energy:0,state:0.0021420237608253956
# train Loss: 0.0085382288
# epoch:123
# energy:0,state:0.0024079058784991503
# energy:0,state:0.0017862912500277162
# energy:0,state:0.0008310810662806034
# energy:0,state:0.00130878621712327
# energy:0,state:0.0021593624260276556
# train Loss: 0.0084934268
# epoch:124
# energy:0,state:0.0023586666211485863
# energy:0,state:0.0018821918638423085
# energy:0,state:0.0007732616504654288
# energy:0,state:0.0013108747079968452
# energy:0,state:0.00215739943087101
# train Loss: 0.0084823943
# epoch:125
# energy:0,state:0.0023672617971897125
# energy:0,state:0.0018576906295493245
# energy:0,state:0.0007984250551089644
# energy:0,state:0.0012887029442936182
# energy:0,state:0.0021779199596494436
# train Loss: 0.0084900004
# epoch:126
# energy:0,state:0.0024138728622347116
# energy:0,state:0.0018109354423359036
# energy:0,state:0.0007955800974741578
# energy:0,state:0.001271534594707191
# energy:0,state:0.002146634506061673
# train Loss: 0.0084385575
# epoch:127
# energy:0,state:0.0023820502683520317
# energy:0,state:0.0017919744132086635
# energy:0,state:0.0007634463254362345
# energy:0,state:0.001326912548393011
# energy:0,state:0.0021555328276008368
# train Loss: 0.0084199164
# epoch:128
# energy:0,state:0.0023238149005919695
# energy:0,state:0.0019232812337577343
# energy:0,state:0.0007528545684181154
# energy:0,state:0.0012844332959502935
# energy:0,state:0.0021709189750254154
# train Loss: 0.0084553030
# epoch:129
# energy:0,state:0.002429873449727893
# energy:0,state:0.0018128373194485903
# energy:0,state:0.0007609169115312397
# energy:0,state:0.0012753453338518739
# energy:0,state:0.0021760391537100077
# train Loss: 0.0084550122
# epoch:130
# energy:0,state:0.0023941181134432554
# energy:0,state:0.0018248003907501698
# energy:0,state:0.0007700001588091254
# energy:0,state:0.001281887642107904
# energy:0,state:0.0021314704790711403
# train Loss: 0.0084022768
# epoch:131
# energy:0,state:0.0023773224093019962
# energy:0,state:0.0018515191040933132
# energy:0,state:0.000734341680072248
# energy:0,state:0.0013048354303464293
# energy:0,state:0.002169051207602024
# train Loss: 0.0084370698
# epoch:132
# energy:0,state:0.0023406425025314093
# energy:0,state:0.0018392547499388456
# energy:0,state:0.0007391869439743459
# energy:0,state:0.001300701522268355
# energy:0,state:0.0021575093269348145
# train Loss: 0.0083772950
# epoch:133
# energy:0,state:0.0024096709676086903
# energy:0,state:0.00177793949842453
# energy:0,state:0.0007359100272879004
# energy:0,state:0.001272982102818787
# energy:0,state:0.0021562445908784866
# train Loss: 0.0083527472
# epoch:134
# energy:0,state:0.0023599094711244106
# energy:0,state:0.001938813948072493
# energy:0,state:0.0007402619230560958
# energy:0,state:0.0012938022846356034
# energy:0,state:0.0021788813173770905
# train Loss: 0.0085116689
# epoch:135
# energy:0,state:0.0024397140368819237
# energy:0,state:0.0017568314215168357
# energy:0,state:0.0007636456284672022
# energy:0,state:0.001288886647671461
# energy:0,state:0.0021904362365603447
# train Loss: 0.0084395140
# epoch:136
# energy:0,state:0.0023550933692604303
# energy:0,state:0.0018705928232520819
# energy:0,state:0.0007633402710780501
# energy:0,state:0.001303571742027998
# energy:0,state:0.002185175195336342
# train Loss: 0.0084777734
# epoch:137
# energy:0,state:0.002383038168773055
# energy:0,state:0.0017526127630844712
# energy:0,state:0.000766196520999074
# energy:0,state:0.0013809045776724815
# energy:0,state:0.0021715869661420584
# train Loss: 0.0084543390
# epoch:138
# energy:0,state:0.0023262216709554195
# energy:0,state:0.0018798267701640725
# energy:0,state:0.0007304701721295714
# energy:0,state:0.0013819780433550477
# energy:0,state:0.0021838375832885504
# train Loss: 0.0085023342
# epoch:139
# energy:0,state:0.0023544381838291883
# energy:0,state:0.0017138378461822867
# energy:0,state:0.0007510156719945371
# energy:0,state:0.0013736513210460544
# energy:0,state:0.002224205294623971
# train Loss: 0.0084171483
# epoch:140
# energy:0,state:0.00234591425396502
# energy:0,state:0.001861824537627399
# energy:0,state:0.0007173132617026567
# energy:0,state:0.0013469277182593942
# energy:0,state:0.002270558848977089
# train Loss: 0.0085425386
# epoch:141
# energy:0,state:0.0023348508402705193
# energy:0,state:0.0017535212682560086
# energy:0,state:0.0007762228487990797
# energy:0,state:0.0013568369904533029
# energy:0,state:0.002313838107511401
# train Loss: 0.0085352701
# epoch:142
# energy:0,state:0.002393888309597969
# energy:0,state:0.001818082295358181
# energy:0,state:0.0006988287204876542
# energy:0,state:0.001319047180004418
# energy:0,state:0.002215735614299774
# train Loss: 0.0084455821
# epoch:143
# energy:0,state:0.002349314745515585
# energy:0,state:0.0018707815324887633
# energy:0,state:0.0007686753524467349
# energy:0,state:0.0013384887715801597
# energy:0,state:0.002193577354773879
# train Loss: 0.0085208378
# epoch:144
# energy:0,state:0.002411713358014822
# energy:0,state:0.0017428591381758451
# energy:0,state:0.0006901949527673423
# energy:0,state:0.0012906715273857117
# energy:0,state:0.0021663003135472536
# train Loss: 0.0083017393
# epoch:145
# energy:0,state:0.00232328986749053
# energy:0,state:0.0018981758039444685
# energy:0,state:0.0006999815814197063
# energy:0,state:0.00129640509840101
# energy:0,state:0.0021834562066942453
# train Loss: 0.0084013086
# epoch:146
# energy:0,state:0.0023979172110557556
# energy:0,state:0.0017519078683108091
# energy:0,state:0.0006936576683074236
# energy:0,state:0.0012993691489100456
# energy:0,state:0.002157255308702588
# train Loss: 0.0083001072
# epoch:147
# energy:0,state:0.002344957087188959
# energy:0,state:0.00182671332731843
# energy:0,state:0.000667216198053211
# energy:0,state:0.0012923008762300014
# energy:0,state:0.0021832198835909367
# train Loss: 0.0083144074
# epoch:148
# energy:0,state:0.0023003474343568087
# energy:0,state:0.0018053586827591062
# energy:0,state:0.0006673422176390886
# energy:0,state:0.0013155087362974882
# energy:0,state:0.0021567342337220907
# train Loss: 0.0082452913
# epoch:149
# energy:0,state:0.002372658345848322
# energy:0,state:0.0017788239056244493
# energy:0,state:0.0006382342544384301
# energy:0,state:0.001276948256418109
# energy:0,state:0.0021776417270302773
# train Loss: 0.0082443065
# epoch:150
# energy:0,state:0.0023001262452453375
# energy:0,state:0.0017772960709407926
# energy:0,state:0.0006297620129771531
# energy:0,state:0.0012992393458262086
# energy:0,state:0.0021599954925477505
# train Loss: 0.0081664192
# epoch:151
# energy:0,state:0.002316487953066826
# energy:0,state:0.0018121827160939574
# energy:0,state:0.0006239012000150979
# energy:0,state:0.0012779018143191934
# energy:0,state:0.0021612115669995546
# train Loss: 0.0081916853
# epoch:152
# energy:0,state:0.0023222104646265507
# energy:0,state:0.0017525579314678907
# energy:0,state:0.0006202755030244589
# energy:0,state:0.0012705718399956822
# energy:0,state:0.0021557211875915527
# train Loss: 0.0081213369
# epoch:153
# energy:0,state:0.0023125698789954185
# energy:0,state:0.001812185626477003
# energy:0,state:0.000615059572737664
# energy:0,state:0.0012742822291329503
# energy:0,state:0.0021558236330747604
# train Loss: 0.0081699209
# epoch:154
# energy:0,state:0.0023230076767504215
# energy:0,state:0.0017743806820362806
# energy:0,state:0.0006130858673714101
# energy:0,state:0.0012655241880565882
# energy:0,state:0.0021569652017205954
# train Loss: 0.0081329636
# epoch:155
# energy:0,state:0.002318096812814474
# energy:0,state:0.0017838471103459597
# energy:0,state:0.0005925762816332281
# energy:0,state:0.0012622112408280373
# energy:0,state:0.002159503987058997
# train Loss: 0.0081162354
# epoch:156
# energy:0,state:0.002311130054295063
# energy:0,state:0.0017666195053607225
# energy:0,state:0.0005834210896864533
# energy:0,state:0.001294988440349698
# energy:0,state:0.002146156970411539
# train Loss: 0.0081023161
# epoch:157
# energy:0,state:0.0023159878328442574
# energy:0,state:0.0018350562313571572
# energy:0,state:0.0005816720658913255
# energy:0,state:0.0012761845719069242
# energy:0,state:0.0021798801608383656
# train Loss: 0.0081887809
# epoch:158
# energy:0,state:0.002330315299332142
# energy:0,state:0.0017120823031291366
# energy:0,state:0.0005872505716979504
# energy:0,state:0.0012712109601125121
# energy:0,state:0.002141012344509363
# train Loss: 0.0080418715
# epoch:159
# energy:0,state:0.002323055174201727
# energy:0,state:0.0018090158700942993
# energy:0,state:0.0005795211181975901
# energy:0,state:0.00127858342602849
# energy:0,state:0.0021692102309316397
# train Loss: 0.0081593858
# epoch:160
# energy:0,state:0.0022949944250285625
# energy:0,state:0.0017709166277199984
# energy:0,state:0.0005751096177846193
# energy:0,state:0.001299103838391602
# energy:0,state:0.0021581610199064016
# train Loss: 0.0080982855
# epoch:161
# energy:0,state:0.0023532425984740257
# energy:0,state:0.0017890047747641802
# energy:0,state:0.0005663991905748844
# energy:0,state:0.0012645588722079992
# energy:0,state:0.002167341997846961
# train Loss: 0.0081405474
# epoch:162
# energy:0,state:0.002338937483727932
# energy:0,state:0.001728009432554245
# energy:0,state:0.0005667394143529236
# energy:0,state:0.0012785526923835278
# energy:0,state:0.0021474563982337713
# train Loss: 0.0080596954
# epoch:163
# energy:0,state:0.002299138344824314
# energy:0,state:0.001866971724666655
# energy:0,state:0.0005618893192149699
# energy:0,state:0.001314834807999432
# energy:0,state:0.002209683880209923
# train Loss: 0.0082525181
# epoch:164
# energy:0,state:0.0023116820957511663
# energy:0,state:0.0017146897735074162
# energy:0,state:0.0006226016557775438
# energy:0,state:0.0012956848368048668
# energy:0,state:0.0021628502290695906
# train Loss: 0.0081075086
# epoch:165
# energy:0,state:0.0023594603408128023
# energy:0,state:0.0017570799682289362
# energy:0,state:0.0006101359031163156
# energy:0,state:0.0012545527424663305
# energy:0,state:0.002175985835492611
# train Loss: 0.0081572148
# epoch:166
# energy:0,state:0.0023473536130040884
# energy:0,state:0.001789203262887895
# energy:0,state:0.0005453704507090151
# energy:0,state:0.0013652811758220196
# energy:0,state:0.0021890318021178246
# train Loss: 0.0082362403
# epoch:167
# energy:0,state:0.002288665622472763
# energy:0,state:0.0018032609950751066
# energy:0,state:0.0005965803284198046
# energy:0,state:0.0013811957323923707
# energy:0,state:0.002182823373004794
# train Loss: 0.0082525261
# epoch:168
# energy:0,state:0.002370926784351468
# energy:0,state:0.0017203992465510964
# energy:0,state:0.0005712556303478777
# energy:0,state:0.0013203914277255535
# energy:0,state:0.002226851647719741
# train Loss: 0.0082098247
# epoch:169
# energy:0,state:0.002340699080377817
# energy:0,state:0.0019395574927330017
# energy:0,state:0.0006194224115461111
# energy:0,state:0.0013504126109182835
# energy:0,state:0.002329631242901087
# train Loss: 0.0085797228
# epoch:170
# energy:0,state:0.0024166624061763287
# energy:0,state:0.0016451781848445535
# energy:0,state:0.000715329428203404
# energy:0,state:0.0013964411336928606
# energy:0,state:0.0023977586533874273
# train Loss: 0.0085713698
# epoch:171
# energy:0,state:0.002381920116022229
# energy:0,state:0.001760572544299066
# energy:0,state:0.0006133138667792082
# energy:0,state:0.0013763324823230505
# energy:0,state:0.0022543633822351694
# train Loss: 0.0083865024
# epoch:172
# energy:0,state:0.0023489182349294424
# energy:0,state:0.0017905571730807424
# energy:0,state:0.0006954140844754875
# energy:0,state:0.00139912823215127
# energy:0,state:0.002180206123739481
# train Loss: 0.0084142238
# epoch:173
# energy:0,state:0.002378745935857296
# energy:0,state:0.0017147778999060392
# energy:0,state:0.0006180375348776579
# energy:0,state:0.001414114492945373
# energy:0,state:0.00222151936031878
# train Loss: 0.0083471952
# epoch:174
# energy:0,state:0.0023235559929162264
# energy:0,state:0.0020471494644880295
# energy:0,state:0.0006461719167418778
# energy:0,state:0.0013299710117280483
# energy:0,state:0.002242464805021882
# train Loss: 0.0085893132
# epoch:175
# energy:0,state:0.002503691939637065
# energy:0,state:0.001679881475865841
# energy:0,state:0.0006627978291362524
# energy:0,state:0.001345390104688704
# energy:0,state:0.0022502995561808348
# train Loss: 0.0084420609
# epoch:176
# energy:0,state:0.002397457603365183
# energy:0,state:0.0019545936957001686
# energy:0,state:0.0007030534907244146
# energy:0,state:0.001331681152805686
# energy:0,state:0.0022363681346178055
# train Loss: 0.0086231541
# epoch:177
# energy:0,state:0.0024178919848054647
# energy:0,state:0.0017846524715423584
# energy:0,state:0.0006201084470376372
# energy:0,state:0.0013926589163020253
# energy:0,state:0.0022341804578900337
# train Loss: 0.0084494923
# epoch:178
# energy:0,state:0.00243161479011178
# energy:0,state:0.0017227812204509974
# energy:0,state:0.0006495880079455674
# energy:0,state:0.0013627964071929455
# energy:0,state:0.002218300709500909
# train Loss: 0.0083850811
# epoch:179
# energy:0,state:0.0023367831017822027
# energy:0,state:0.0017859875224530697
# energy:0,state:0.0006084546912461519
# energy:0,state:0.0012946927454322577
# energy:0,state:0.002170837251469493
# train Loss: 0.0081967553
# epoch:180
# energy:0,state:0.0022942740470170975
# energy:0,state:0.0017678606091067195
# energy:0,state:0.0005832796450704336
# energy:0,state:0.0012854461092501879
# energy:0,state:0.0021529654040932655
# train Loss: 0.0080838258
# epoch:181
# energy:0,state:0.0023136064410209656
# energy:0,state:0.0017415949841961265
# energy:0,state:0.000536147563252598
# energy:0,state:0.0012604828225448728
# energy:0,state:0.00216608471237123
# train Loss: 0.0080179165
# epoch:182
# energy:0,state:0.0022811584640294313
# energy:0,state:0.0017825185786932707
# energy:0,state:0.0005153909442014992
# energy:0,state:0.001245112274773419
# energy:0,state:0.002143096411600709
# train Loss: 0.0079672767
# epoch:183
# energy:0,state:0.0022851922549307346
# energy:0,state:0.0017436272464692593
# energy:0,state:0.0005229593953117728
# energy:0,state:0.0012626084499061108
# energy:0,state:0.0021501174196600914
# train Loss: 0.0079645048
# epoch:184
# energy:0,state:0.002256360836327076
# energy:0,state:0.001746037625707686
# energy:0,state:0.0004912902950309217
# energy:0,state:0.0012550712563097477
# energy:0,state:0.0021737131755799055
# train Loss: 0.0079224732
# epoch:185
# energy:0,state:0.002257999498397112
# energy:0,state:0.0017491518519818783
# energy:0,state:0.0004936933401040733
# energy:0,state:0.0012459837598726153
# energy:0,state:0.002161928452551365
# train Loss: 0.0079087569
# epoch:186
# energy:0,state:0.002278434345498681
# energy:0,state:0.0017216885462403297
# energy:0,state:0.00047729353536851704
# energy:0,state:0.0012430254137143493
# energy:0,state:0.00216065370477736
# train Loss: 0.0078810955
# epoch:187
# energy:0,state:0.0022557033225893974
# energy:0,state:0.0017626452026888728
# energy:0,state:0.0004734935355372727
# energy:0,state:0.001248713000677526
# energy:0,state:0.0021707811392843723
# train Loss: 0.0079113362
# epoch:188
# energy:0,state:0.002284934278577566
# energy:0,state:0.0017184600001201034
# energy:0,state:0.0004701610014308244
# energy:0,state:0.0012410023482516408
# energy:0,state:0.0021641715429723263
# train Loss: 0.0078787292
# epoch:189
# energy:0,state:0.0022573836613446474
# energy:0,state:0.0017202678136527538
# energy:0,state:0.0004627722373697907
# energy:0,state:0.0012541372561827302
# energy:0,state:0.00215835589915514
# train Loss: 0.0078529169
# epoch:190
# energy:0,state:0.0022681280970573425
# energy:0,state:0.0017658420838415623
# energy:0,state:0.00046058549196459353
# energy:0,state:0.0012462870217859745
# energy:0,state:0.0021663669031113386
# train Loss: 0.0079072096
# epoch:191
# energy:0,state:0.0022679476533085108
# energy:0,state:0.001706985873170197
# energy:0,state:0.00046144321095198393
# energy:0,state:0.0012391131604090333
# energy:0,state:0.0021479222923517227
# train Loss: 0.0078234122
# epoch:192
# energy:0,state:0.0022844516206532717
# energy:0,state:0.001745599671266973
# energy:0,state:0.0004513082676567137
# energy:0,state:0.001242928672581911
# energy:0,state:0.0021655107848346233
# train Loss: 0.0078897990
# epoch:193
# energy:0,state:0.0022677110973745584
# energy:0,state:0.0017322046915069222
# energy:0,state:0.00045526205212809145
# energy:0,state:0.0012449718778952956
# energy:0,state:0.0021607328671962023
# train Loss: 0.0078608826
# epoch:194
# energy:0,state:0.0022817119024693966
# energy:0,state:0.001724199391901493
# energy:0,state:0.0004304302856326103
# energy:0,state:0.0012437220430001616
# energy:0,state:0.002157797571271658
# train Loss: 0.0078378612
# epoch:195
# energy:0,state:0.002263373229652643
# energy:0,state:0.0017615732504054904
# energy:0,state:0.00044023976079188287
# energy:0,state:0.0012578422902151942
# energy:0,state:0.0021773637272417545
# train Loss: 0.0079003923
# epoch:196
# energy:0,state:0.002283290959894657
# energy:0,state:0.001711671706289053
# energy:0,state:0.00043937814189121127
# energy:0,state:0.0012491898378357291
# energy:0,state:0.0021716789342463017
# train Loss: 0.0078552096
# epoch:197
# energy:0,state:0.002245956799015403
# energy:0,state:0.0017201687442138791
# energy:0,state:0.00044248197809793055
# energy:0,state:0.001253747963346541
# energy:0,state:0.0021663326770067215
# train Loss: 0.0078286882
# epoch:198
# energy:0,state:0.002262572757899761
# energy:0,state:0.0017381623620167375
# energy:0,state:0.0004347219946794212
# energy:0,state:0.0012484429171308875
# energy:0,state:0.002167105209082365
# train Loss: 0.0078510052
# epoch:199
# energy:0,state:0.002245937241241336
# energy:0,state:0.0017233309336006641
# energy:0,state:0.00043781212298199534
# energy:0,state:0.0012377379462122917
# energy:0,state:0.0021420149132609367
# train Loss: 0.0077868332
# epoch:200
# energy:0,state:0.002280841115862131
# energy:0,state:0.0017267316579818726
# energy:0,state:0.00043053299305029213
# energy:0,state:0.0012646003160625696
# energy:0,state:0.0021701303776353598
# train Loss: 0.0078728365
# epoch:201
# energy:0,state:0.0022540753707289696
# energy:0,state:0.0017613775562494993
# energy:0,state:0.00043264604755677283
# energy:0,state:0.0012608995893970132
# energy:0,state:0.002172655425965786
# train Loss: 0.0078816540
# epoch:202
# energy:0,state:0.0023023050744086504
# energy:0,state:0.0017006684793159366
# energy:0,state:0.000413852627389133
# energy:0,state:0.0012835166417062283
# energy:0,state:0.0021777877118438482
# train Loss: 0.0078781305
# epoch:203
# energy:0,state:0.0022776557598263025
# energy:0,state:0.0017978943651542068
# energy:0,state:0.0004255823150742799
# energy:0,state:0.0012861165450885892
# energy:0,state:0.0022148163989186287
# train Loss: 0.0080020654
# epoch:204
# energy:0,state:0.002315741730853915
# energy:0,state:0.0016909134574234486
# energy:0,state:0.00044322293251752853
# energy:0,state:0.001305163954384625
# energy:0,state:0.00222345651127398
# train Loss: 0.0079784986
# epoch:205
# energy:0,state:0.0022507933899760246
# energy:0,state:0.0017282357439398766
# energy:0,state:0.0004481109499465674
# energy:0,state:0.0012832422507926822
# energy:0,state:0.0021908432245254517
# train Loss: 0.0079012256
# epoch:206
# energy:0,state:0.002279840409755707
# energy:0,state:0.0017294372664764524
# energy:0,state:0.00044376723235473037
# energy:0,state:0.0012785327853634953
# energy:0,state:0.002196685643866658
# train Loss: 0.0079282633
# epoch:207
# energy:0,state:0.0022439591120928526
# energy:0,state:0.0017137819668278098
# energy:0,state:0.0004610680334735662
# energy:0,state:0.0012537676375359297
# energy:0,state:0.002136802999302745
# train Loss: 0.0078093797
# epoch:208
# energy:0,state:0.0022834702394902706
# energy:0,state:0.001806937507353723
# energy:0,state:0.0004894414450973272
# energy:0,state:0.0012555585708469152
# energy:0,state:0.0021758018992841244
# train Loss: 0.0080112097
# epoch:209
# energy:0,state:0.0023074380587786436
# energy:0,state:0.0016945329261943698
# energy:0,state:0.00045304730883799493
# energy:0,state:0.0012282802490517497
# energy:0,state:0.002187128411605954
# train Loss: 0.0078704270
# epoch:210
# energy:0,state:0.0022771500516682863
# energy:0,state:0.0017882032552734017
# energy:0,state:0.00041574789793230593
# energy:0,state:0.0012699523940682411
# energy:0,state:0.002180089009925723
# train Loss: 0.0079311426
# epoch:211
# energy:0,state:0.002295957412570715
# energy:0,state:0.0016918843612074852
# energy:0,state:0.000426788697950542
# energy:0,state:0.0012517932336777449
# energy:0,state:0.00219398713670671
# train Loss: 0.0078604108
# epoch:212
# energy:0,state:0.0022493579890578985
# energy:0,state:0.001712788362056017
# energy:0,state:0.0003953784762416035
# energy:0,state:0.001265008351765573
# energy:0,state:0.0021560362074524164
# train Loss: 0.0077785694
# epoch:213
# energy:0,state:0.0022657057270407677
# energy:0,state:0.0017330924747511744
# energy:0,state:0.0004234501684550196
# energy:0,state:0.0012617218308150768
# energy:0,state:0.0021774659398943186
# train Loss: 0.0078614361
# epoch:214
# energy:0,state:0.0022776464466005564
# energy:0,state:0.0016872468404471874
# energy:0,state:0.00039821051177568734
# energy:0,state:0.0012421966530382633
# energy:0,state:0.0021882671862840652
# train Loss: 0.0077935676
# epoch:215
# energy:0,state:0.0022506401874125004
# energy:0,state:0.0017009475268423557
# energy:0,state:0.0003978518070653081
# energy:0,state:0.0012537888251245022
# energy:0,state:0.002196380402892828
# train Loss: 0.0077996087
# epoch:216
# energy:0,state:0.0022523971274495125
# energy:0,state:0.0017093265196308494
# energy:0,state:0.0004035515012219548
# energy:0,state:0.0012305218260735273
# energy:0,state:0.002170531079173088
# train Loss: 0.0077663281
# epoch:217
# energy:0,state:0.0022334707900881767
# energy:0,state:0.0016968456329777837
# energy:0,state:0.0004031155549455434
# energy:0,state:0.0012408409966155887
# energy:0,state:0.0021411150228232145
# train Loss: 0.0077153880
# epoch:218
# energy:0,state:0.0022498182952404022
# energy:0,state:0.0017555288504809141
# energy:0,state:0.00041527164285071194
# energy:0,state:0.0012434488162398338
# energy:0,state:0.0021733539178967476
# train Loss: 0.0078374215
# epoch:219
# energy:0,state:0.0022528814151883125
# energy:0,state:0.001692835590802133
# energy:0,state:0.00039043487049639225
# energy:0,state:0.0012227857951074839
# energy:0,state:0.0021587524097412825
# train Loss: 0.0077176901
# epoch:220
# energy:0,state:0.002256767125800252
# ...
# epoch:399
# energy:0,state:0.0020767650566995144
# energy:0,state:0.00156262400560081
# energy:0,state:0.00025736208772286773
# energy:0,state:0.0011965290177613497
# energy:0,state:0.002146936720237136
# train Loss: 0.0072402169
# epoch:400
# energy:0,state:0.0020249318331480026
# energy:0,state:0.0016462091589346528
# energy:0,state:0.00023473847249988467
# energy:0,state:0.0012070090742781758
# energy:0,state:0.002117515541613102
# train Loss: 0.0072304041
# epoch:401
# energy:0,state:0.0020322499331086874
# energy:0,state:0.0015895136166363955
# energy:0,state:0.0002457144728396088
# energy:0,state:0.0011729418765753508
# energy:0,state:0.0021353878546506166
# train Loss: 0.0071758078
# epoch:402
# energy:0,state:0.002032013377174735
# energy:0,state:0.001671938574872911
# energy:0,state:0.0002446223224978894
# energy:0,state:0.0011849012225866318
# energy:0,state:0.0021669205743819475
# train Loss: 0.0073003961
# epoch:403
# energy:0,state:0.0020695202983915806
# energy:0,state:0.0015607309760525823
# energy:0,state:0.00024883414153009653
# energy:0,state:0.0011781292269006371
# energy:0,state:0.0021747881546616554
# train Loss: 0.0072320028
# epoch:404
# energy:0,state:0.002040514722466469
# energy:0,state:0.0017005220288410783
# energy:0,state:0.00023577321553602815
# energy:0,state:0.001188412425108254
# energy:0,state:0.0021930551156401634
# train Loss: 0.0073582775
# epoch:405
# energy:0,state:0.0021010737400501966
# energy:0,state:0.0015554828569293022
# energy:0,state:0.00025370687944814563
# energy:0,state:0.0011799533385783434
# energy:0,state:0.0021951200906187296
# train Loss: 0.0072853369
# epoch:406
# energy:0,state:0.0020520833786576986
# energy:0,state:0.0016976636834442616
# energy:0,state:0.00024600460892543197
# energy:0,state:0.0011971734929829836
# energy:0,state:0.0022067546378821135
# train Loss: 0.0073996798
# epoch:407
# energy:0,state:0.0021254895254969597
# energy:0,state:0.001536100055091083
# energy:0,state:0.00026096749934367836
# energy:0,state:0.001179025275632739
# energy:0,state:0.002207641489803791
# train Loss: 0.0073092238
# epoch:408
# energy:0,state:0.002057385165244341
# energy:0,state:0.0016820330638438463
# energy:0,state:0.00024465611204504967
# energy:0,state:0.00117906229570508
# energy:0,state:0.0021875945385545492
# train Loss: 0.0073507312
# epoch:409
# energy:0,state:0.0020906468853354454
# energy:0,state:0.0015463202726095915
# energy:0,state:0.0002564542228356004
# energy:0,state:0.0011787406401708722
# energy:0,state:0.002180700656026602
# train Loss: 0.0072528627
# epoch:410
# energy:0,state:0.0020669198129326105
# energy:0,state:0.0016894350992515683
# energy:0,state:0.00023877520288806409
# energy:0,state:0.0011573656229302287
# energy:0,state:0.002181311370804906
# train Loss: 0.0073338071
# epoch:411
# energy:0,state:0.0020757783204317093
# energy:0,state:0.0015581571497023106
# energy:0,state:0.00025544140953570604
# energy:0,state:0.0011924307327717543
# energy:0,state:0.002167818136513233
# train Loss: 0.0072496257
# epoch:412
# energy:0,state:0.0020713084377348423
# energy:0,state:0.001701024011708796
# energy:0,state:0.00024299576762132347
# energy:0,state:0.0011604895116761327
# energy:0,state:0.002164261881262064
# train Loss: 0.0073400796
# epoch:413
# energy:0,state:0.0020746535155922174
# energy:0,state:0.0015868303598836064
# energy:0,state:0.00026540737599134445
# energy:0,state:0.0012009070487692952
# energy:0,state:0.002147803781554103
# train Loss: 0.0072756021
# epoch:414
# energy:0,state:0.002072744769975543
# energy:0,state:0.0017104168655350804
# energy:0,state:0.00025906311930157244
# energy:0,state:0.0011750473640859127
# energy:0,state:0.002140484983101487
# train Loss: 0.0073577571
# epoch:415
# energy:0,state:0.002071723574772477
# energy:0,state:0.0016055878950282931
# energy:0,state:0.0002909997710958123
# energy:0,state:0.0012231532018631697
# energy:0,state:0.002145028207451105
# train Loss: 0.0073364927
# epoch:416
# energy:0,state:0.002060845261439681
# energy:0,state:0.0017182051669806242
# energy:0,state:0.000290972413495183
# energy:0,state:0.0012146959779784083
# energy:0,state:0.0021526168566197157
# train Loss: 0.0074373357
# epoch:417
# energy:0,state:0.002081101294606924
# energy:0,state:0.0016112790908664465
# energy:0,state:0.0003227725683245808
# energy:0,state:0.0012637823820114136
# energy:0,state:0.0021630669943988323
# train Loss: 0.0074420023
# epoch:418
# energy:0,state:0.0020474970806390047
# energy:0,state:0.0017600888386368752
# energy:0,state:0.000312465475872159
# energy:0,state:0.0012255400652065873
# energy:0,state:0.0021962786559015512
# train Loss: 0.0075418701
# epoch:419
# energy:0,state:0.002109006978571415
# energy:0,state:0.0015748951118439436
# energy:0,state:0.00032211298821493983
# energy:0,state:0.0012595542939379811
# energy:0,state:0.0022220590617507696
# train Loss: 0.0074876284
# epoch:420
# energy:0,state:0.0020258172880858183
# energy:0,state:0.0017186598852276802
# energy:0,state:0.00028616792405955493
# energy:0,state:0.0012290492886677384
# energy:0,state:0.0021604483481496572
# train Loss: 0.0074201427
# epoch:421
# energy:0,state:0.002083082217723131
# energy:0,state:0.0015470609068870544
# energy:0,state:0.00029265499324537814
# energy:0,state:0.0012331902980804443
# energy:0,state:0.0022343695163726807
# train Loss: 0.0073903579
# epoch:422
# energy:0,state:0.002042006468400359
# energy:0,state:0.0016281150747090578
# energy:0,state:0.00024747918359935284
# energy:0,state:0.0011827669804915786
# energy:0,state:0.002166611608117819
# train Loss: 0.0072669793
# epoch:423
# energy:0,state:0.0020874200854450464
# energy:0,state:0.0015638652257621288
# energy:0,state:0.00025643932167440653
# energy:0,state:0.00122688221745193
# energy:0,state:0.0022051178384572268
# train Loss: 0.0073397247
# epoch:424
# energy:0,state:0.0020899297669529915
# energy:0,state:0.0016108143609017134
# energy:0,state:0.00023992016213014722
# energy:0,state:0.001139779924415052
# energy:0,state:0.002130401087924838
# train Loss: 0.0072108453
# epoch:425
# energy:0,state:0.0020715920254588127
# energy:0,state:0.0015909954672679305
# energy:0,state:0.00024234790180344135
# energy:0,state:0.00123887718655169
# energy:0,state:0.0021614045836031437
# train Loss: 0.0073052172
# epoch:426
# energy:0,state:0.0020676993299275637
# energy:0,state:0.0016164678381755948
# energy:0,state:0.0002325248351553455
# energy:0,state:0.001144561916589737
# energy:0,state:0.0020866645500063896
# train Loss: 0.0071479185
# epoch:427
# energy:0,state:0.002064639935269952
# energy:0,state:0.001593569410033524
# energy:0,state:0.0002350509021198377
# energy:0,state:0.0012383379507809877
# energy:0,state:0.0021293633617460728
# train Loss: 0.0072609616
# epoch:428
# energy:0,state:0.002022725297138095
# energy:0,state:0.0016375897685065866
# energy:0,state:0.00022982046357356012
# energy:0,state:0.001158374478109181
# energy:0,state:0.0020939225796610117
# train Loss: 0.0071424326
# epoch:429
# energy:0,state:0.0020503243431448936
# energy:0,state:0.001578470808453858
# energy:0,state:0.0002360141952522099
# energy:0,state:0.0012254469329491258
# energy:0,state:0.0021300085354596376
# train Loss: 0.0072202648
# epoch:430
# energy:0,state:0.0020164649467915297
# energy:0,state:0.001657012733630836
# energy:0,state:0.0002374015311943367
# energy:0,state:0.001163176610134542
# energy:0,state:0.002134923590347171
# train Loss: 0.0072089794
# epoch:431
# energy:0,state:0.0020523197017610073
# energy:0,state:0.0015742839314043522
# energy:0,state:0.0002415699273115024
# energy:0,state:0.0011949631152674556
# energy:0,state:0.0021451362408697605
# train Loss: 0.0072082729
# epoch:432
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-f6ea3b781839>", line 60, in <module>
#     model_ft = train_model(model_ft, optimizer_ft, num_epochs=1000)
#   File "<ipython-input-9-f6ea3b781839>", line 29, in train_model
#     for batch_i, (q, q_next) in enumerate(data_dict[phase]):
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 291, in __iter__
#     return _MultiProcessingDataLoaderIter(self)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 764, in __init__
#     self._try_put_index()
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1005, in _try_put_index
#     self._index_queues[worker_queue_idx].put((self._send_idx, index))
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/multiprocessing/queues.py", line 87, in put
#     self._start_thread()
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/multiprocessing/queues.py", line 170, in _start_thread
#     self._thread.start()
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
#   File "/Users/shaan/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 98825) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-9-f6ea3b781839> in <module>
#      59 optimizer_ft = torch.optim.Adam(params, 1e-2)
# ---> 60 model_ft = train_model(model_ft, optimizer_ft, num_epochs=1000)
#
# <ipython-input-9-f6ea3b781839> in train_model(model, optimizer, num_epochs)
#      28             # Iterate over data.
# ---> 29             for batch_i, (q, q_next) in enumerate(data_dict[phase]):
#      30                 if phase == 'train':
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     290         else:
# --> 291             return _MultiProcessingDataLoaderIter(self)
#     292
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     763         for _ in range(2 * self._num_workers):
# --> 764             self._try_put_index()
#     765
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_put_index(self)
#    1004
# -> 1005         self._index_queues[worker_queue_idx].put((self._send_idx, index))
#    1006         self._task_info[self._send_idx] = (worker_queue_idx,)
#
# ~/opt/anaconda3/envs/main/lib/python3.7/multiprocessing/queues.py in put(self, obj, block, timeout)
#      86             if self._thread is None:
# ---> 87                 self._start_thread()
#      88             self._buffer.append(obj)
#
# ~/opt/anaconda3/envs/main/lib/python3.7/multiprocessing/queues.py in _start_thread(self)
#     169         debug('doing self._thread.start()')
# --> 170         self._thread.start()
#     171         debug('... done self._thread.start()')
#
# ~/opt/anaconda3/envs/main/lib/python3.7/threading.py in start(self)
#     851         try:
# --> 852             _start_new_thread(self._bootstrap, ())
#     853         except Exception:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
loss_coll = np.array(loss_collater)

# %%
plt.plot(loss_coll[:,0],label='state_loss')
plt.plot(loss_coll[:,1],label='energy_loss')
plt.yscale('log')
plt.legend()
plt.xlabel('iterations')

# %%
it = iter(data_dict['train'])
q,q_next = next(it)

# %%
plt.plot(model_ft.forward(q.float()).detach().numpy())

# %%
plt.plot(loss_collater)
plt.yscale('log')

# %%
q=torch.tensor(tnow[0]).float().reshape(-1,4)
q.to(device)
q.requires_grad = True
loss = 0
coll = []
for _ in range(100):
    nstep = model_ft.next_step(q)
    coll.append(nstep.detach().numpy()[0])
    q=nstep

# %%
coll = np.array(coll)

# %%
N = 1000
fig,axs = plt.subplots(1,2,figsize=(7,5))
sns.scatterplot(x=range(N),y=coll[:N,3],ax=axs[0])
sns.scatterplot(x=range(N),y=tnext[:N,3],ax=axs[0])
sns.scatterplot(x=range(N),y=coll[:N,1],ax=axs[1])
sns.scatterplot(x=range(N),y=tnext[:N,1],ax=axs[1])
plt.tight_layout()

# %%
# x1_p,y1_p,x2_p,y2_p = theta_to_cart(np.array(coll))

# %%
# x1_p.shape

# %%
# sns.scatterplot(x=x2_p[:50],y=y2_p[:50])
# sns.scatterplot(x=x2[:50],y=y2[:50])

# %%
N = 500
fig,axs = plt.subplots(1,2,figsize=(15,10))
sns.scatterplot(x=range(N),y=y2_p[:N],ax=axs[0])
sns.scatterplot(x=range(N),y=y2[:N],ax=axs[0])
sns.scatterplot(x=range(N),y=x2_p[:N],ax=axs[1])
sns.scatterplot(x=range(N),y=x2[:N],ax=axs[1])
plt.tight_layout()

# %%
x2.shape

# %%
torch.pi

# %%
np.pi

# %%
for batch_i, (q, dq) in enumerate(data_dict['train']):
    print(batch_i)

# %%
model_ft.M_matrix(q[:,:2].float())

# %%
model_ft.Minv

# %%
torch.inverse(model_ft.M[:2,:2])
